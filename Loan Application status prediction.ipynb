# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8672\1876574325.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd # for data wrangling purpose

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

# %%
# Importing Loan Predication CSV dataset file using pandas
df=pd.read_csv('C:\\Users\\admin\\Downloads\\loan_prediction.csv')

# %%
print('No of Rows:',df.shape[0])
print('No. of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 614
# No. of Columns: 13
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # Statistical Analysis
# Before Going for Statistical exploration of data, first check integrity of data & Missing value
#
# Data Integrity Check

# %%
df.duplicated().sum() # This check any if any duplicated entry exit in dataset
# Out:
# 0

# %% [markdown]
# # Datatype Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# # Missing value check

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                    Missing Values  % Missing data
# Credit_History                 50        8.143322
# Self_Employed                  32        5.211726
# LoanAmount                     22        3.583062
# Dependents                     15        2.442997
# Loan_Amount_Term               14        2.280130
# Gender                         13        2.117264
# Married                         3        0.488599
# Loan_ID                         0        0.000000
# Education                       0        0.000000
# ApplicantIncome                 0        0.000000
# CoapplicantIncome               0        0.000000
# Property_Area                   0        0.000000
# Loan_Status                     0        0.000000

# %% [markdown]
# # Start with Enlisting Value counts & Sub-categories of different categorial features available

# %%
category=['Gender','Married','Dependents','Education','Self_Employed',
          'Loan_Amount_Term','Property_Area','Credit_History','Loan_Status']
for i in category:
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Gender
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64
# ====================================================================================================
# Married
# Married
# Yes    398
# No     213
# Name: count, dtype: int64
# ====================================================================================================
# Dependents
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64
# ====================================================================================================
# Education
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# ====================================================================================================
# Self_Employed
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64
# ====================================================================================================
# Loan_Amount_Term
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64
# ====================================================================================================
# Property_Area
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64
# ====================================================================================================
# Credit_History
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64
# ====================================================================================================
# Loan_Status
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64
# ====================================================================================================

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1
category=['Gender','Married','Dependents','Education','Self_Employed',
          'Loan_Amount_Term','Property_Area','Credit_History','Loan_Status']
for i in category:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.countplot(df[i])
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# # Let check outliers for missing values Numerical variable having missing values by plotting boxplot.

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot( y='LoanAmount', data=df,color='cyan')
plt.ylabel('Loan Amount',fontsize=15)
plt.subplot(1,2,2)
sns.distplot(df['LoanAmount'], color='b')
plt.xlabel('Loan Amount',fontsize=15)
plt.tight_layout()
plt.show()

# %%
print("Mean of Loan Amount:",df['LoanAmount'].mean())
print("Median of Loan Amount:",df['LoanAmount'].median())
# Out:
# Mean of Loan Amount: 146.41216216216216
# Median of Loan Amount: 128.0

# %%
# Imputating Missing value with mode for categorical features
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Married'].fillna(df['Married'].mode()[0],inplace=True)

# Imputation of Numerical features
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0],inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %% [markdown]
# # Missing Value Check After Imputation

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                    Missing Values  % Missing data
# Loan_ID                         0             0.0
# Gender                          0             0.0
# Married                         0             0.0
# Dependents                      0             0.0
# Education                       0             0.0
# Self_Employed                   0             0.0
# ApplicantIncome                 0             0.0
# CoapplicantIncome               0             0.0
# LoanAmount                      0             0.0
# Loan_Amount_Term                0             0.0
# Credit_History                  0             0.0
# Property_Area                   0             0.0
# Loan_Status                     0             0.0

# %% [markdown]
# # Statistical Matrix

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(12,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Target Variable

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Loan_Status'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Loan Status', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Loan_Status',data=df,ax=ax[1])
ax[1].set_title('Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 8
#       6 ax[0].set_title('Loan Status', fontsize=20,fontweight ='bold')
#       7 ax[0].set_ylabel('')
# ----> 8 sns.countplot('Loan_Status',data=df,ax=ax[1])
#       9 ax[1].set_title('Loan Status',fontsize=20,fontweight ='bold')
#      10 ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
#
# TypeError: countplot() got multiple values for argument 'data'

# %% [markdown]
# # Gender Vs Loan Status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Gender'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Gender', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Gender',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Gender Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       6 ax[0].set_title('Gender', fontsize=20,fontweight ='bold')
#       7 ax[0].set_ylabel('')
# ----> 8 sns.countplot('Gender',hue="Loan_Status",data=df,ax=ax[1])
#       9 ax[1].set_title('Gender Vs Loan Status',fontsize=20,fontweight ='bold')
#      10 ax[1].set_xlabel("Loan Status",fontsize=18,fontweight ='bold')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
pip install Jinja2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Jinja2
#   Obtaining dependency information for Jinja2 from https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl.metadata
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/3f/14/c3554d512d5f9100a95e737502f4a2323a1959f6d0d01e0d0997b35f7b10/MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.2 kB ? eta -:--:--
#    ---------------------------------------- 133.2/133.2 kB 4.0 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Installing collected packages: MarkupSafe, Jinja2
# Successfully installed Jinja2-3.1.3 MarkupSafe-2.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
pd.crosstab(df['Gender'],df["Loan_Status"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5dd3b_row0_col0, #T_5dd3b_row0_col1, #T_5dd3b_row0_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5dd3b_row1_col0 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_5dd3b_row1_col1 {
#   background-color: #379b66;
#   color: #f1f1f1;
# }
# #T_5dd3b_row1_col2 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_5dd3b_row2_col0, #T_5dd3b_row2_col1, #T_5dd3b_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5dd3b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_5dd3b_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_5dd3b_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_5dd3b_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dd3b_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_5dd3b_row0_col0" class="data row0 col0" >37</td>
#       <td id="T_5dd3b_row0_col1" class="data row0 col1" >75</td>
#       <td id="T_5dd3b_row0_col2" class="data row0 col2" >112</td>
#     </tr>
#     <tr>
#       <th id="T_5dd3b_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_5dd3b_row1_col0" class="data row1 col0" >155</td>
#       <td id="T_5dd3b_row1_col1" class="data row1 col1" >347</td>
#       <td id="T_5dd3b_row1_col2" class="data row1 col2" >502</td>
#     </tr>
#     <tr>
#       <th id="T_5dd3b_level0_row2" class="row_heading level0 row2" >All</th>
#       <td id="T_5dd3b_row2_col0" class="data row2 col0" >192</td>
#       <td id="T_5dd3b_row2_col1" class="data row2 col1" >422</td>
#       <td id="T_5dd3b_row2_col2" class="data row2 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Married Vs Loan Status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Married'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Married', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Married',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Married Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Married",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 8
#       6 ax[0].set_title('Married', fontsize=20,fontweight ='bold')
#       7 ax[0].set_ylabel('')
# ----> 8 sns.countplot('Married',hue="Loan_Status",data=df,ax=ax[1])
#       9 ax[1].set_title('Married Vs Loan Status',fontsize=20,fontweight ='bold')
#      10 ax[1].set_xlabel("Married",fontsize=18,fontweight ='bold')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
pd.crosstab([df['Gender'],df['Married']],[df.Loan_Status],margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_7853e_row0_col0 {
#   background-color: #a100ff;
#   color: #f1f1f1;
# }
# #T_7853e_row0_col1 {
#   background-color: #e200ff;
#   color: #f1f1f1;
# }
# #T_7853e_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_7853e_row1_col0, #T_7853e_row1_col1, #T_7853e_row1_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_7853e_row2_col0 {
#   background-color: #0400ff;
#   color: #f1f1f1;
# }
# #T_7853e_row2_col1 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_7853e_row2_col2 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_7853e_row3_col0 {
#   background-color: #00ff66;
#   color: #000000;
# }
# #T_7853e_row3_col1 {
#   background-color: #05ff00;
#   color: #000000;
# }
# #T_7853e_row3_col2 {
#   background-color: #00ff1b;
#   color: #000000;
# }
# #T_7853e_row4_col0, #T_7853e_row4_col1, #T_7853e_row4_col2 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7853e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_7853e_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_7853e_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_7853e_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="index_name level1" >Married</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7853e_level0_row0" class="row_heading level0 row0" rowspan="2">Female</th>
#       <th id="T_7853e_level1_row0" class="row_heading level1 row0" >No</th>
#       <td id="T_7853e_row0_col0" class="data row0 col0" >29</td>
#       <td id="T_7853e_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_7853e_row0_col2" class="data row0 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_7853e_level1_row1" class="row_heading level1 row1" >Yes</th>
#       <td id="T_7853e_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_7853e_row1_col1" class="data row1 col1" >24</td>
#       <td id="T_7853e_row1_col2" class="data row1 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_7853e_level0_row2" class="row_heading level0 row2" rowspan="2">Male</th>
#       <th id="T_7853e_level1_row2" class="row_heading level1 row2" >No</th>
#       <td id="T_7853e_row2_col0" class="data row2 col0" >50</td>
#       <td id="T_7853e_row2_col1" class="data row2 col1" >83</td>
#       <td id="T_7853e_row2_col2" class="data row2 col2" >133</td>
#     </tr>
#     <tr>
#       <th id="T_7853e_level1_row3" class="row_heading level1 row3" >Yes</th>
#       <td id="T_7853e_row3_col0" class="data row3 col0" >105</td>
#       <td id="T_7853e_row3_col1" class="data row3 col1" >264</td>
#       <td id="T_7853e_row3_col2" class="data row3 col2" >369</td>
#     </tr>
#     <tr>
#       <th id="T_7853e_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_7853e_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_7853e_row4_col0" class="data row4 col0" >192</td>
#       <td id="T_7853e_row4_col1" class="data row4 col1" >422</td>
#       <td id="T_7853e_row4_col2" class="data row4 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Let check how number dependents play here.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Dependents'].value_counts().plot.pie(explode=[0,0.1,0.15,0.2],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('No. of Dependents', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Dependents',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('No. of Dependents Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Dependents",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 8
#       6 ax[0].set_title('No. of Dependents', fontsize=20,fontweight ='bold')
#       7 ax[0].set_ylabel('')
# ----> 8 sns.countplot('Dependents',hue="Loan_Status",data=df,ax=ax[1])
#       9 ax[1].set_title('No. of Dependents Vs Loan Status',fontsize=20,fontweight ='bold')
#      10 ax[1].set_xlabel("Dependents",fontsize=18,fontweight ='bold')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
pd.crosstab([df['Dependents']],[df.Loan_Status,df['Gender']],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_5b471_row0_col0 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_5b471_row0_col1 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_5b471_row0_col2 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_5b471_row0_col3 {
#   background-color: #7ebe66;
#   color: #000000;
# }
# #T_5b471_row0_col4 {
#   background-color: #73b966;
#   color: #f1f1f1;
# }
# #T_5b471_row1_col0 {
#   background-color: #e2f066;
#   color: #000000;
# }
# #T_5b471_row1_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_5b471_row1_col2 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_5b471_row1_col3 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_5b471_row1_col4 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_5b471_row2_col0, #T_5b471_row3_col0, #T_5b471_row3_col1, #T_5b471_row3_col2, #T_5b471_row3_col3, #T_5b471_row3_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5b471_row2_col1 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_5b471_row2_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_5b471_row2_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_5b471_row2_col4 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_5b471_row4_col0, #T_5b471_row4_col1, #T_5b471_row4_col2, #T_5b471_row4_col3, #T_5b471_row4_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5b471">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_5b471_level0_col0" class="col_heading level0 col0" colspan="2">N</th>
#       <th id="T_5b471_level0_col2" class="col_heading level0 col2" colspan="2">Y</th>
#       <th id="T_5b471_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Gender</th>
#       <th id="T_5b471_level1_col0" class="col_heading level1 col0" >Female</th>
#       <th id="T_5b471_level1_col1" class="col_heading level1 col1" >Male</th>
#       <th id="T_5b471_level1_col2" class="col_heading level1 col2" >Female</th>
#       <th id="T_5b471_level1_col3" class="col_heading level1 col3" >Male</th>
#       <th id="T_5b471_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dependents</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b471_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b471_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_5b471_row0_col1" class="data row0 col1" >86</td>
#       <td id="T_5b471_row0_col2" class="data row0 col2" >56</td>
#       <td id="T_5b471_row0_col3" class="data row0 col3" >191</td>
#       <td id="T_5b471_row0_col4" class="data row0 col4" >360</td>
#     </tr>
#     <tr>
#       <th id="T_5b471_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b471_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_5b471_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_5b471_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_5b471_row1_col3" class="data row1 col3" >53</td>
#       <td id="T_5b471_row1_col4" class="data row1 col4" >102</td>
#     </tr>
#     <tr>
#       <th id="T_5b471_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b471_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_5b471_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_5b471_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_5b471_row2_col3" class="data row2 col3" >71</td>
#       <td id="T_5b471_row2_col4" class="data row2 col4" >101</td>
#     </tr>
#     <tr>
#       <th id="T_5b471_level0_row3" class="row_heading level0 row3" >3+</th>
#       <td id="T_5b471_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_5b471_row3_col1" class="data row3 col1" >16</td>
#       <td id="T_5b471_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_5b471_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_5b471_row3_col4" class="data row3 col4" >51</td>
#     </tr>
#     <tr>
#       <th id="T_5b471_level0_row4" class="row_heading level0 row4" >All</th>
#       <td id="T_5b471_row4_col0" class="data row4 col0" >37</td>
#       <td id="T_5b471_row4_col1" class="data row4 col1" >155</td>
#       <td id="T_5b471_row4_col2" class="data row4 col2" >75</td>
#       <td id="T_5b471_row4_col3" class="data row4 col3" >347</td>
#       <td id="T_5b471_row4_col4" class="data row4 col4" >614</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df['Dependents'],df['Gender']],[df.Loan_Status],margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f89f9_row0_col0, #T_f89f9_row0_col1, #T_f89f9_row0_col2, #T_f89f9_row3_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_f89f9_row1_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_f89f9_row1_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_f89f9_row1_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_f89f9_row2_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f89f9_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f89f9_row2_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f89f9_row3_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_f89f9_row3_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_f89f9_row4_col0, #T_f89f9_row6_col0, #T_f89f9_row6_col1, #T_f89f9_row6_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f89f9_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_f89f9_row4_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f89f9_row5_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_f89f9_row5_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_f89f9_row5_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_f89f9_row7_col0, #T_f89f9_row7_col1, #T_f89f9_row7_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_f89f9_row8_col0, #T_f89f9_row8_col1, #T_f89f9_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f89f9">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_f89f9_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_f89f9_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_f89f9_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dependents</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f89f9_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#       <th id="T_f89f9_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_f89f9_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_f89f9_row0_col1" class="data row0 col1" >56</td>
#       <td id="T_f89f9_row0_col2" class="data row0 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_f89f9_row1_col0" class="data row1 col0" >86</td>
#       <td id="T_f89f9_row1_col1" class="data row1 col1" >191</td>
#       <td id="T_f89f9_row1_col2" class="data row1 col2" >277</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#       <th id="T_f89f9_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_f89f9_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_f89f9_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_f89f9_row2_col2" class="data row2 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_f89f9_row3_col0" class="data row3 col0" >30</td>
#       <td id="T_f89f9_row3_col1" class="data row3 col1" >53</td>
#       <td id="T_f89f9_row3_col2" class="data row3 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#       <th id="T_f89f9_level1_row4" class="row_heading level1 row4" >Female</th>
#       <td id="T_f89f9_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_f89f9_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_f89f9_row4_col2" class="data row4 col2" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level1_row5" class="row_heading level1 row5" >Male</th>
#       <td id="T_f89f9_row5_col0" class="data row5 col0" >23</td>
#       <td id="T_f89f9_row5_col1" class="data row5 col1" >71</td>
#       <td id="T_f89f9_row5_col2" class="data row5 col2" >94</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level0_row6" class="row_heading level0 row6" rowspan="2">3+</th>
#       <th id="T_f89f9_level1_row6" class="row_heading level1 row6" >Female</th>
#       <td id="T_f89f9_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_f89f9_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_f89f9_row6_col2" class="data row6 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level1_row7" class="row_heading level1 row7" >Male</th>
#       <td id="T_f89f9_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_f89f9_row7_col1" class="data row7 col1" >32</td>
#       <td id="T_f89f9_row7_col2" class="data row7 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_f89f9_level0_row8" class="row_heading level0 row8" >All</th>
#       <th id="T_f89f9_level1_row8" class="row_heading level1 row8" ></th>
#       <td id="T_f89f9_row8_col0" class="data row8 col0" >192</td>
#       <td id="T_f89f9_row8_col1" class="data row8 col1" >422</td>
#       <td id="T_f89f9_row8_col2" class="data row8 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# # Education Vs Loan status

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('prism')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Education'].value_counts().plot.pie(explode=[0,0.1],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Education', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Education',hue="Loan_Status",data=df,ax=ax[1])
ax[1].set_title('Education Vs Loan Status',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Education",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 8
#       6 ax[0].set_title('Education', fontsize=20,fontweight ='bold')
#       7 ax[0].set_ylabel('')
# ----> 8 sns.countplot('Education',hue="Loan_Status",data=df,ax=ax[1])
#       9 ax[1].set_title('Education Vs Loan Status',fontsize=20,fontweight ='bold')
#      10 ax[1].set_xlabel("Education",fontsize=18,fontweight ='bold')
#
# TypeError: countplot() got multiple values for argument 'data'

# %%
 pd.crosstab([df['Education'],df['Gender']],[df.Loan_Status],margins=True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ade70_row0_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_ade70_row0_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_ade70_row0_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ade70_row1_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_ade70_row1_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_ade70_row1_col2 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_ade70_row2_col0, #T_ade70_row2_col1, #T_ade70_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ade70_row3_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_ade70_row3_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_ade70_row3_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_ade70_row4_col0, #T_ade70_row4_col1, #T_ade70_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ade70">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Loan_Status</th>
#       <th id="T_ade70_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_ade70_level0_col1" class="col_heading level0 col1" >Y</th>
#       <th id="T_ade70_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="index_name level1" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ade70_level0_row0" class="row_heading level0 row0" rowspan="2">Graduate</th>
#       <th id="T_ade70_level1_row0" class="row_heading level1 row0" >Female</th>
#       <td id="T_ade70_row0_col0" class="data row0 col0" >31</td>
#       <td id="T_ade70_row0_col1" class="data row0 col1" >61</td>
#       <td id="T_ade70_row0_col2" class="data row0 col2" >92</td>
#     </tr>
#     <tr>
#       <th id="T_ade70_level1_row1" class="row_heading level1 row1" >Male</th>
#       <td id="T_ade70_row1_col0" class="data row1 col0" >109</td>
#       <td id="T_ade70_row1_col1" class="data row1 col1" >279</td>
#       <td id="T_ade70_row1_col2" class="data row1 col2" >388</td>
#     </tr>
#     <tr>
#       <th id="T_ade70_level0_row2" class="row_heading level0 row2" rowspan="2">Not Graduate</th>
#       <th id="T_ade70_level1_row2" class="row_heading level1 row2" >Female</th>
#       <td id="T_ade70_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_ade70_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_ade70_row2_col2" class="data row2 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_ade70_level1_row3" class="row_heading level1 row3" >Male</th>
#       <td id="T_ade70_row3_col0" class="data row3 col0" >46</td>
#       <td id="T_ade70_row3_col1" class="data row3 col1" >68</td>
#       <td id="T_ade70_row3_col2" class="data row3 col2" >114</td>
#     </tr>
#     <tr>
#       <th id="T_ade70_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_ade70_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_ade70_row4_col0" class="data row4 col0" >192</td>
#       <td id="T_ade70_row4_col1" class="data row4 col1" >422</td>
#       <td id="T_ade70_row4_col2" class="data row4 col2" >614</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# # Encoding categorical data

# %%
Category=['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status']

# %%
pip install -U scikit-learn scipy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/40/77/91f92b2fddbd14201bf36cd0c0e7279f1501a88e7a00ef11261c4b95bb7a/scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/ed/6f/ba2b2f14391291dd47d17da78c3ee644fb3a2fd6bddde664381c1968eda9/scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.6 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 541.3 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python312\site-packages (3.8.3)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/7d/ca/e7bd1876a341ed8c456095962a582696cac1691cb6e55bd5ead15a755c5d/matplotlib-3.8.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading matplotlib-3.8.4-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (
3 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.3/7.7 MB 5.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/7.7 MB 5.3 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.7 MB 5.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.7 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.1/7.7 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------- -------------- 4.8/7.7 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.0/7.7 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.2/7.7 MB 5.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.5/7.7 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.7 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.7 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.7/7.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.0/7.7 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.7 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.5/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 4.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.3
#     Uninstalling matplotlib-3.8.3:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\admin\\appdata\\roaming\\python\\python312\\site-packages\\matplotlib\\backends\\_backend_agg.cp312-win_amd64.pyd'
# Check the permissions.
#
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          0              0
# 1  LP001003       1        1          1          0              0
# 2  LP001005       1        1          0          0              1
# 3  LP001006       1        1          0          1              0
# 4  LP001008       1        0          0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# 2             1.0              2            1
# 3             1.0              2            1
# 4             1.0              2            1

# %% [markdown]
# # Feature selection and Engineering
# 1. Outliers Detection and Removal

# %%
Numerical =['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']

# %%
plt.figure(figsize=(12,8),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.boxplot(df[column],color='c')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
# Droping unnecessary columns
df.drop(["Loan_ID"], axis=1, inplace=True)

# %%
df['Dependents'] = df.Dependents.map({'0':0,'1':1,'2':2,'3+':3})

# %%
df['Dependents'] =pd.to_numeric(df['Dependents'])

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy() # reassigning the changed dataframe name to our original dataframe name
# Out:
# Shape of the dataframe before removing outliers:  (614, 12)
# Shape of the dataframe after removing outliers:  (577, 12)
# Percentage of data loss post outlier removal:  6.026058631921824

# %% [markdown]
# # Data Loss

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((614-577)/614)*100,'%')
# Out:
# Percentage Data Loss : 6.026058631921824 %

# %% [markdown]
# # 2. Skewness of features

# %%
plt.figure(figsize=(22,5),facecolor='white')
plotnum=1
for col in Numerical:
    if plotnum<=4:
        plt.subplot(1,4,plotnum)
        sns.distplot(df[col],color='r')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
df.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      2.148522
# CoapplicantIncome    1.350517
# LoanAmount           1.151525
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %%
# Removing skewness using yeo-johnson  method to get better prediction
skew = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
df[skew] = scaler.fit_transform(df[skew].values)
df[skew].head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount
# 0         0.681780          -1.122446    0.000771
# 1         0.234783           0.744117    0.000771
# 2        -0.527201          -1.122446   -1.437336
# 3        -0.791972           0.895786   -0.153545
# 4         0.728848          -1.122446    0.238260

# %% [markdown]
# # Checking skewness after using yeo-johnson ethod

# %%
df.skew()
# Out:
# Gender              -1.622920
# Married             -0.630211
# Dependents           1.052106
# Education            1.306588
# Self_Employed        2.252848
# ApplicantIncome      0.027981
# CoapplicantIncome   -0.191876
# LoanAmount           0.048425
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# Property_Area       -0.055332
# Loan_Status         -0.822635
# dtype: float64

# %% [markdown]
# # 3. Corrleation

# %%
df.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.378997    0.188162   0.045696      -0.006207
# Married            0.378997  1.000000    0.329900   0.024817      -0.015779
# Dependents         0.188162  0.329900    1.000000   0.069814       0.044543
# Education          0.045696  0.024817    0.069814   1.000000      -0.007139
# Self_Employed     -0.006207 -0.015779    0.044543  -0.007139       1.000000
# ApplicantIncome    0.058590 -0.024783    0.105994  -0.176074       0.212260
# CoapplicantIncome  0.234551  0.335820    0.004109   0.049739      -0.087338
# LoanAmount         0.172146  0.181878    0.131772  -0.128715       0.117218
# Loan_Amount_Term  -0.104983 -0.127348   -0.087389  -0.090523      -0.032914
# Credit_History     0.013172  0.019308   -0.020288  -0.075217      -0.016390
# Property_Area     -0.026340  0.010595    0.002327  -0.068596      -0.028253
# Loan_Status        0.017408  0.089026    0.017872  -0.092658      -0.026525
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.058590           0.234551    0.172146
# Married                  -0.024783           0.335820    0.181878
# Dependents                0.105994           0.004109    0.131772
# Education                -0.176074           0.049739   -0.128715
# Self_Employed             0.212260          -0.087338    0.117218
# ApplicantIncome           1.000000          -0.360946    0.432154
# CoapplicantIncome        -0.360946           1.000000    0.200081
# LoanAmount                0.432154           0.200081    1.000000
# Loan_Amount_Term         -0.069429           0.000951    0.049057
# Credit_History            0.028825           0.006564   -0.003626
# Property_Area            -0.011364          -0.074476   -0.098090
# Loan_Status              -0.002484           0.079344   -0.023609
#
#                    Loan_Amount_Term  Credit_History  Property_Area  \
# Gender                    -0.104983        0.013172      -0.026340
# Married                   -0.127348        0.019308       0.010595
# Dependents                -0.087389       -0.020288       0.002327
# Education                 -0.090523       -0.075217      -0.068596
# Self_Employed             -0.032914       -0.016390      -0.028253
# ApplicantIncome           -0.069429        0.028825      -0.011364
# CoapplicantIncome          0.000951        0.006564      -0.074476
# LoanAmount                 0.049057       -0.003626      -0.098090
# Loan_Amount_Term           1.000000        0.027392      -0.057004
# Credit_History             0.027392        1.000000      -0.008121
# Property_Area             -0.057004       -0.008121       1.000000
# Loan_Status               -0.020291        0.560936       0.026507
#
#                    Loan_Status
# Gender                0.017408
# Married               0.089026
# Dependents            0.017872
# Education            -0.092658
# Self_Employed        -0.026525
# ApplicantIncome      -0.002484
# CoapplicantIncome     0.079344
# LoanAmount           -0.023609
# Loan_Amount_Term     -0.020291
# Credit_History        0.560936
# Property_Area         0.026507
# Loan_Status           1.000000

# %%
plt.figure(figsize=(21,13))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df.corr()['Loan_Status'].drop(['Loan_Status']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Loan_Status',fontsize = 18)
plt.show()

# %% [markdown]
# # 4. Checking Multicollinearity between features using variance_inflation_factor

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting statsmodels
#   Obtaining dependency information for statsmodels from https://files.pythonhosted.org/packages/bf/53/1e7077d1bf324c1b1055dedb72e1410d089e459a86940e25b28f545f776e/statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\admin\appdata\roaming\python\python312\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\admin\appdata\roaming\python\python312\site-packages (from statsmodels) (2.2.0)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Obtaining dependency information for patsy>=0.5.6 from https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl.metadata
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from statsmodels) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.4)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.2-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB 217.9 kB/s eta 0:00:46
#    ---------------------------------------- 0.0/9.8 MB 393.8 kB/s eta 0:00:25
#     --------------------------------------- 0.2/9.8 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/9.8 MB 2.0 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/9.8 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.8 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/9.8 MB 3.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.8 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/9.8 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/9.8 MB 3.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.8 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.9/9.8 MB 3.3 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 3.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.5/9.8 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.8/9.8 MB 3.8 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.8 MB 3.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.8 MB 3.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 3.8 MB/s eta 0:00:02
#    -------------- ------------------------- 3.6/9.8 MB 3.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.8 MB 3.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.1/9.8 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/9.8 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 4.6/9.8 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.8/9.8 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 4.8/9.8 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.8 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.3/9.8 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/9.8 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.9/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 6.1/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.5/9.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.8 MB 4.1 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.8 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 4.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.8 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.0/9.8 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.2/9.8 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.5/9.8 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/9.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.0 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.9 kB ? eta -:--:--
#    ---------------------------------------- 233.9/233.9 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#           VIF           Features
# 0    6.119789             Gender
# 1    3.963538            Married
# 2    1.778377         Dependents
# 3    1.355469          Education
# 4    1.197219      Self_Employed
# 5    1.756726    ApplicantIncome
# 6    1.596438  CoapplicantIncome
# 7    1.548450         LoanAmount
# 8   10.415255   Loan_Amount_Term
# 9    9.483180     Credit_History
# 10   2.654799      Property_Area
# 11   4.818436        Loan_Status

# %% [markdown]
# # 5. Balanceing Imbalanced target feature

# %%
df.Loan_Status.value_counts()
# Out:
# Loan_Status
# 1    398
# 0    179
# Name: count, dtype: int64

# %% [markdown]
# # Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imblearn
#   Obtaining dependency information for imblearn from https://files.pythonhosted.org/packages/81/a7/4179e6ebfd654bd0eac0b9c06125b8b4c96a9d0a8ff9e9507eb2a26d2d7e/imblearn-0.0-py2.py3-none-any.whl.metadata
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/6e/1b/66764ecf370e797759be06fb38c11640ea1f9456ae10f8640a33cfa726ea/imbalanced_learn-0.12.2-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.12.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.13.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.12.2-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/258.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/258.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/258.0 kB ? eta -:--:--
#    ------------ -------------------------- 81.9/258.0 kB 651.6 kB/s eta 0:00:01
#    ------------------------------ --------- 194.6/258.0 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 258.0/258.0 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.12.2 imblearn-0.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
# Splitting data in target and dependent feature
X = df.drop(['Loan_Status'], axis =1)
Y = df['Loan_Status']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# Loan_Status
# 1    398
# 0    398
# Name: count, dtype: int64

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (557, 11)
# Training target vector size: (557,)
# Test feature matrix size: (239, 11)
# Test target vector size: (239,)

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8284518828451883 on Random_state 78

# %% [markdown]
# # Logistics Regression Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=78, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8284518828451883
#
#
# Confusion matrix of Logistics Regression :
#  [[ 80  30]
#  [ 11 118]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.88      0.73      0.80       110
#            1       0.80      0.91      0.85       129
#
#     accuracy                           0.83       239
#    macro avg       0.84      0.82      0.82       239
# weighted avg       0.83      0.83      0.83       239

# %% [markdown]
# # Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(25):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.4753329597178616
# RMSE value for k=  2 is: 0.5215041008435626
# RMSE value for k=  3 is: 0.4387124562248739
# RMSE value for k=  4 is: 0.513418276223035
# RMSE value for k=  5 is: 0.4840553929365547
# RMSE value for k=  6 is: 0.513418276223035
# RMSE value for k=  7 is: 0.47971400126799746
# RMSE value for k=  8 is: 0.5093272287453544
# RMSE value for k=  9 is: 0.4753329597178616
# RMSE value for k=  10 is: 0.5093272287453544
# RMSE value for k=  11 is: 0.47091116165974684
# RMSE value for k=  12 is: 0.47971400126799746
# RMSE value for k=  13 is: 0.4664474480124446
# RMSE value for k=  14 is: 0.47971400126799746
# RMSE value for k=  15 is: 0.47971400126799746
# RMSE value for k=  16 is: 0.49262341019056577
# RMSE value for k=  17 is: 0.4883581921595791
# RMSE value for k=  18 is: 0.50104493321917
# RMSE value for k=  19 is: 0.49262341019056577
# RMSE value for k=  20 is: 0.4968520148758506
# RMSE value for k=  21 is: 0.49262341019056577
# RMSE value for k=  22 is: 0.4968520148758506
# RMSE value for k=  23 is: 0.4840553929365547
# RMSE value for k=  24 is: 0.4840553929365547
# RMSE value for k=  25 is: 0.4753329597178616

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(25), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# # Applying other classification algorithm

# %%
pip install metrics plot_roc_curve
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting metrics
#   Downloading metrics-0.3.3.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# ERROR: Could not find a version that satisfies the requirement plot_roc_curve (from versions: none)
# ERROR: No matching distribution found for plot_roc_curve
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\admin\AppData\Roaming\Python\Python312\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.675      0.72327044 0.79245283 0.83018868 0.77987421]
# Mean Score : 0.7601572327044025
# Std deviation : 0.054678255652072856
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.6875     0.74213836 0.81132075 0.78616352 0.81132075]
# Mean Score : 0.7676886792452831
# Std deviation : 0.04739594641653733
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.68125    0.71069182 0.78616352 0.74842767 0.79245283]
# Mean Score : 0.7437971698113207
# Std deviation : 0.04287618225618176
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.70625    0.66666667 0.79245283 0.75471698 0.78616352]
# Mean Score : 0.7412500000000001
# Std deviation : 0.04818295854517011
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.75       0.76100629 0.77987421 0.79874214 0.78616352]
# Mean Score : 0.7751572327044026
# Std deviation : 0.017508692964874294
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.775      0.77358491 0.8427673  0.81132075 0.8490566 ]
# Mean Score : 0.8103459119496854
# Std deviation : 0.03209772319807462
#
#
# ============================================================================================================
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.75625    0.78616352 0.8490566  0.83018868 0.87421384]
# Mean Score : 0.8191745283018868
# Std deviation : 0.04264457339041313
#
#
# ============================================================================================================

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {  'bootstrap': [True], 'max_depth': [5, 10,20,40,50,60], 
              'max_features': ['auto', 'log2'], 
              'criterion':['gini','entropy'],
              'n_estimators': [5, 10, 15 ,25,50,60,70]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [CV 1/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 1/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 2/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 2/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 3/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 3/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 4/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 4/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 5/5; 1/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5
# [CV 5/5; 1/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 1/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 1/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 2/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 3/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 4/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5; 2/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10
# [CV 5/5; 2/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 1/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 2/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 2/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 3/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 3/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 4/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 4/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 5/5; 3/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15
# [CV 5/5; 3/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 1/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 1/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 2/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 2/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 3/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 3/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 4/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 4/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 5/5; 4/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25
# [CV 5/5; 4/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 1/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 1/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 2/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 3/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 4/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5; 5/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50
# [CV 5/5; 5/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 1/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 2/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 2/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 3/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 3/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 4/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 4/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 5/5; 6/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60
# [CV 5/5; 6/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 1/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 1/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 2/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 2/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 3/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 3/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 4/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 4/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 5/5; 7/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70
# [CV 5/5; 7/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 1/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 1/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.759 total time=   0.0s
# [CV 2/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 2/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.652 total time=   0.0s
# [CV 3/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 3/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.739 total time=   0.0s
# [CV 4/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 4/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.748 total time=   0.0s
# [CV 5/5; 8/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5
# [CV 5/5; 8/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=5;, score=0.748 total time=   0.0s
# [CV 1/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 1/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.768 total time=   0.0s
# [CV 2/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 2/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.670 total time=   0.0s
# [CV 3/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 3/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.874 total time=   0.0s
# [CV 4/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 4/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.766 total time=   0.0s
# [CV 5/5; 9/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10
# [CV 5/5; 9/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=10;, score=0.721 total time=   0.0s
# [CV 1/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 1/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.732 total time=   0.0s
# [CV 2/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 2/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.688 total time=   0.0s
# [CV 3/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 3/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.820 total time=   0.0s
# [CV 4/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 4/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.766 total time=   0.0s
# [CV 5/5; 10/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15
# [CV 5/5; 10/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=15;, score=0.748 total time=   0.0s
# [CV 1/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 1/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.750 total time=   0.0s
# [CV 2/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV 2/5; 11/168] END bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25;, score=0.696 total time=   0.1s
# [CV 3/5; 11/168] START bootstrap=True, criterion=gini, max_depth=5, max_features=log2, n_estimators=25
# [CV
5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 4/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.766 total time=   0.3s
# [CV 5/5; 27/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60
# [CV 5/5; 27/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=60;, score=0.766 total time=   0.1s
# [CV 1/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 1/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.768 total time=   0.2s
# [CV 2/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 2/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.741 total time=   0.2s
# [CV 3/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 3/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.874 total time=   0.2s
# [CV 4/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 4/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.775 total time=   0.2s
# [CV 5/5; 28/168] START bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70
# [CV 5/5; 28/168] END bootstrap=True, criterion=gini, max_depth=10, max_features=log2, n_estimators=70;, score=0.793 total time=   0.2s
# [CV 1/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 1/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 2/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 2/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 3/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 3/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 4/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 4/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 5/5; 29/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5
# [CV 5/5; 29/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=5;, score=nan total time=   0.0s
# [CV 1/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 1/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 2/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 3/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 4/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5; 30/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10
# [CV 5/5; 30/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 1/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 2/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 2/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 3/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 3/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 4/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 4/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 5/5; 31/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15
# [CV 5/5; 31/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 1/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 1/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 2/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 2/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 3/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 3/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 4/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 4/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 5/5; 32/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25
# [CV 5/5; 32/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 1/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 1/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 2/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 3/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 4/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5; 33/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50
# [CV 5/5; 33/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 1/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 2/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 2/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 3/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 3/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 4/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 4/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 5/5; 34/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60
# [CV 5/5; 34/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 1/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 1/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 2/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 2/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 3/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 3/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 4/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 4/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 5/5; 35/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70
# [CV 5/5; 35/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 1/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 1/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.768 total time=   0.0s
# [CV 2/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 2/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.696 total time=   0.0s
# [CV 3/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 3/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.820 total time=   0.0s
# [CV 4/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 4/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.775 total time=   0.0s
# [CV 5/5; 36/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5
# [CV 5/5; 36/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=5;, score=0.748 total time=   0.0s
# [CV 1/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 1/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.750 total time=   0.0s
# [CV 2/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 2/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.688 total time=   0.0s
# [CV 3/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 3/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.784 total time=   0.0s
# [CV 4/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 4/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.766 total time=   0.0s
# [CV 5/5; 37/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10
# [CV 5/5; 37/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=10;, score=0.766 total time=   0.0s
# [CV 1/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 1/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.786 total time=   0.0s
# [CV 2/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 2/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 3/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 3/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.811 total time=   0.0s
# [CV 4/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 4/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.784 total time=   0.0s
# [CV 5/5; 38/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15
# [CV 5/5; 38/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=15;, score=0.739 total time=   0.0s
# [CV 1/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 1/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.759 total time=   0.0s
# [CV 2/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 2/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.696 total time=   0.0s
# [CV 3/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 3/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.829 total time=   0.0s
# [CV 4/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 4/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.811 total time=   0.0s
# [CV 5/5; 39/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25
# [CV 5/5; 39/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=25;, score=0.775 total time=   0.0s
# [CV 1/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 1/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.804 total time=   0.1s
# [CV 2/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 2/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 3/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 3/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.820 total time=   0.1s
# [CV 4/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 4/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.775 total time=   0.1s
# [CV 5/5; 40/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50
# [CV 5/5; 40/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=50;, score=0.748 total time=   0.1s
# [CV 1/5; 41/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60
# [CV 1/5; 41/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60;, score=0.768 total time=   0.2s
# [CV 2/5; 41/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60
# [CV 2/5; 41/168] END bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60;, score=0.705 total time=   0.2s
# [CV 3/5; 41/168] START bootstrap=True, criterion=gini, max_depth=20, max_features=log2, n_estimators=60
# ...
# [CV 2/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 3/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 4/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5; 156/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10
# [CV 5/5; 156/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 1/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 2/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 2/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 3/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 3/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 4/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 4/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 5/5; 157/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15
# [CV 5/5; 157/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=15;, score=nan total time=   0.0s
# [CV 1/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 1/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 2/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 2/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 3/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 3/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 4/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 4/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 5/5; 158/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25
# [CV 5/5; 158/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=25;, score=nan total time=   0.0s
# [CV 1/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 1/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 2/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 3/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 4/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5; 159/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50
# [CV 5/5; 159/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 1/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 2/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 2/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 3/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 3/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 4/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 4/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 5/5; 160/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60
# [CV 5/5; 160/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=60;, score=nan total time=   0.0s
# [CV 1/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 1/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 2/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 2/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 3/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 3/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 4/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 4/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 5/5; 161/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70
# [CV 5/5; 161/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=auto, n_estimators=70;, score=nan total time=   0.0s
# [CV 1/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 1/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.768 total time=   0.0s
# [CV 2/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 2/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.696 total time=   0.0s
# [CV 3/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 3/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.838 total time=   0.0s
# [CV 4/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 4/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.784 total time=   0.0s
# [CV 5/5; 162/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5
# [CV 5/5; 162/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=5;, score=0.730 total time=   0.0s
# [CV 1/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 1/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.795 total time=   0.0s
# [CV 2/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 2/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.625 total time=   0.0s
# [CV 3/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 3/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.838 total time=   0.0s
# [CV 4/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 4/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.775 total time=   0.0s
# [CV 5/5; 163/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10
# [CV 5/5; 163/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=10;, score=0.730 total time=   0.0s
# [CV 1/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 1/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.741 total time=   0.0s
# [CV 2/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 2/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.723 total time=   0.0s
# [CV 3/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 3/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.865 total time=   0.0s
# [CV 4/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 4/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.784 total time=   0.0s
# [CV 5/5; 164/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15
# [CV 5/5; 164/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=15;, score=0.775 total time=   0.0s
# [CV 1/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 1/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.759 total time=   0.0s
# [CV 2/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 2/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.732 total time=   0.0s
# [CV 3/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 3/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.829 total time=   0.0s
# [CV 4/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 4/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.802 total time=   0.0s
# [CV 5/5; 165/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25
# [CV 5/5; 165/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=25;, score=0.775 total time=   0.0s
# [CV 1/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 1/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.768 total time=   0.1s
# [CV 2/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 2/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.732 total time=   0.1s
# [CV 3/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 3/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.838 total time=   0.1s
# [CV 4/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 4/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.802 total time=   0.1s
# [CV 5/5; 166/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50
# [CV 5/5; 166/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=50;, score=0.757 total time=   0.1s
# [CV 1/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 1/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.768 total time=   0.1s
# [CV 2/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 2/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.705 total time=   0.1s
# [CV 3/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 3/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.820 total time=   0.1s
# [CV 4/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 4/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.793 total time=   0.1s
# [CV 5/5; 167/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60
# [CV 5/5; 167/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=60;, score=0.757 total time=   0.1s
# [CV 1/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 1/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.786 total time=   0.1s
# [CV 2/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 2/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.714 total time=   0.2s
# [CV 3/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 3/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.838 total time=   0.2s
# [CV 4/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 4/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.802 total time=   0.2s
# [CV 5/5; 168/168] START bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70
# [CV 5/5; 168/168] END bootstrap=True, criterion=entropy, max_depth=60, max_features=log2, n_estimators=70;, score=0.793 total time=   0.2s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 40, 50, 60],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [5, 10, 15, 25, 50, 60, 70]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 60,
#  'max_features': 'log2',
#  'n_estimators': 70}

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Loan_Status_Final.pkl')
# Out:
# ['Loan_Status_Final.pkl']
