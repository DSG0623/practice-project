# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\admin\\Downloads\\zomato_dataset (1).csv')

# %%
df
# Out:
#               Restaurant_Name  Dining_Rating  Delivery_Rating  Dining_Votes  \
# 0                  Doner King            3.9              4.2            39
# 1                  Doner King            3.9              4.2            39
# 2                  Doner King            3.9              4.2            39
# 3                  Doner King            3.9              4.2            39
# 4                  Doner King            3.9              4.2            39
# ...                       ...            ...              ...           ...
# 123652  Ariena Boutique Hotel            3.9              4.2            13
# 123653  Ariena Boutique Hotel            3.9              4.2            13
# 123654  Ariena Boutique Hotel            3.9              4.2            13
# 123655  Ariena Boutique Hotel            3.9              4.2            13
# 123656  Ariena Boutique Hotel            3.9              4.2            13
#
#         Delivery_Votes   Cuisine  Place_Name        City  \
# 0                    0  Fast Food   Malakpet   Hyderabad
# 1                    0  Fast Food   Malakpet   Hyderabad
# 2                    0  Fast Food   Malakpet   Hyderabad
# 3                    0  Fast Food   Malakpet   Hyderabad
# 4                    0  Fast Food   Malakpet   Hyderabad
# ...                ...        ...        ...         ...
# 123652             523      Pizza     Purena      Raipur
# 123653             523      Pizza     Purena      Raipur
# 123654             523      Pizza     Purena      Raipur
# 123655             523      Pizza     Purena      Raipur
# 123656             523      Pizza     Purena      Raipur
#
#                        Item_Name Best_Seller  Votes  Prices
# 0            Platter Kebab Combo  BESTSELLER     84   249.0
# 1        Chicken Rumali Shawarma  BESTSELLER     45   129.0
# 2         Chicken Tandoori Salad         NaN     39   189.0
# 3              Chicken BBQ Salad  BESTSELLER     43   189.0
# 4       Special Doner Wrap Combo    MUST TRY     31   205.0
# ...                          ...         ...    ...     ...
# 123652        Murgh Reshmi Kebab         NaN      0   525.0
# 123653         Murgh Large Tikka         NaN      0   525.0
# 123654     Murgh Chukandri Tikka         NaN      0   525.0
# 123655        Murgh Golden Kebab         NaN      0   525.0
# 123656        Gosht Gilawat Chop  BESTSELLER      0   595.0
#
# [123657 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Restaurant_Name', 'Dining_Rating', 'Delivery_Rating', 'Dining_Votes',
#        'Delivery_Votes', 'Cuisine ', 'Place_Name', 'City', 'Item_Name',
#        'Best_Seller', 'Votes', 'Prices'],
#       dtype='object')

# %%
df.shape
# Out:
# (123657, 12)

# %%
df.size
# Out:
# 1483884

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant_Name  123657 non-null  object
#  1   Dining_Rating    91421 non-null   float64
#  2   Delivery_Rating  122377 non-null  float64
#  3   Dining_Votes     123657 non-null  int64
#  4   Delivery_Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place_Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item_Name        123657 non-null  object
#  9   Best_Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 11.3+ MB

# %%
df.describe()
# Out:
#        Dining_Rating  Delivery_Rating   Dining_Votes  Delivery_Votes  \
# count   91421.000000    122377.000000  123657.000000   123657.000000
# mean        3.822264         3.963184     152.729858      115.763725
# std         0.408693         0.245900     232.214061      243.970828
# min         2.500000         2.500000       0.000000        0.000000
# 25%         3.600000         3.800000       0.000000        0.000000
# 50%         3.900000         4.000000      30.000000        0.000000
# 75%         4.100000         4.100000     217.000000       23.000000
# max         4.800000         4.600000     997.000000      983.000000
#
#                Votes         Prices
# count  123657.000000  123657.000000
# mean       24.666772     241.378399
# std       125.236009     192.830713
# min         0.000000       0.950000
# 25%         0.000000     130.000000
# 50%         0.000000     208.570000
# 75%        15.000000     299.000000
# max      9750.000000   12024.000000

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Restaurant_Name    0.000000
# Dining_Rating      0.260689
# Delivery_Rating    0.010351
# Dining_Votes       0.000000
# Delivery_Votes     0.000000
# Cuisine            0.000000
# Place_Name         0.000000
# City               0.000000
# Item_Name          0.000000
# Best_Seller        0.774036
# Votes              0.000000
# Prices             0.000000
# dtype: float64

# %%
df["Dining_Rating"].fillna(0, inplace=True)
df["Delivery_Rating"].fillna(0, inplace=True)
df["Best_Seller"].fillna("NA", inplace=True)

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Restaurant_Name    0.0
# Dining_Rating      0.0
# Delivery_Rating    0.0
# Dining_Votes       0.0
# Delivery_Votes     0.0
# Cuisine            0.0
# Place_Name         0.0
# City               0.0
# Item_Name          0.0
# Best_Seller        0.0
# Votes              0.0
# Prices             0.0
# dtype: float64

# %%
df["Restaurant_Name"].value_counts()
# Out:
# McDonald's                        2059
# Domino's Pizza                    1435
# Burger King                       1352
# FreshMenu                         1097
# Pizza Hut                         1077
#                                   ...
# Akbar Fast Food                      5
# Al - Hamoor Arabian Restaurant       5
# Sukanta                              4
# Evoke                                4
# Asian Bowls By Zahvi                 4
# Name: Restaurant_Name, Length: 826, dtype: int64

# %%
df["City"].value_counts()
# Out:
#  Hyderabad       15613
#  Jaipur          14438
#  Mumbai          13535
#  Chennai         13100
#  Bangalore       12040
#  Ahmedabad       10178
#  Kolkata          8662
#  Pune             8067
#  Kochi            7759
#  Raipur           7700
#  Lucknow          6455
#  New Delhi        3490
#  Goa              2360
#  Banaswadi          97
#  Ulsoor             66
#  Magrath Road       54
#  Malleshwaram       43
# Name: City, dtype: int64

# %%
# change city names
df['City'] = df['City'].str.replace('Banaswadi|Ulsoor|Magrath Road|Malleshwaram', 'Bangalore')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6728\864462675.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['City'] = df['City'].str.replace('Banaswadi|Ulsoor|Magrath Road|Malleshwaram', 'Bangalore')

# %%
df["City"].value_counts()
# Out:
#  Hyderabad    15613
#  Jaipur       14438
#  Mumbai       13535
#  Chennai      13100
#  Bangalore    12300
#  Ahmedabad    10178
#  Kolkata       8662
#  Pune          8067
#  Kochi         7759
#  Raipur        7700
#  Lucknow       6455
#  New Delhi     3490
#  Goa           2360
# Name: City, dtype: int64

# %% [markdown]
# # EDA
# This section is devoted to extracting insights from the data using a series of visualizations, aimed at addressing the outlined objectives and offering a thorough comprehension of the factors influencing the dynamics of the restaurant industry.
#
# Number of Restaurants by Citites

# %%
res_count=df.groupby(['City'])['Restaurant_Name'].nunique().to_frame().reset_index().sort_values(by='Restaurant_Name', ascending=False).rename(columns={'Restaurant_Name':'Count'})

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='Count',y='City',data=res_count)
ax.bar_label(container=ax.containers[0])

plt.title("Count of Restaurant by Citites")
plt.show()

# %% [markdown]
# # Most popular Restaurant by city

# %%
df['Total_rating'] = df['Dining_Rating'] + df['Delivery_Rating']
df_rating = df.groupby(['City','Restaurant_Name'], as_index= False)['Total_rating'].max()
idx = df_rating.groupby('City')['Total_rating'].idxmax()
df_rating_max = df_rating.loc[idx]
df_rating_max = df_rating_max.set_index('City')
df_rating_max
# Out:
#                  Restaurant_Name  Total_rating
# City
#  Ahmedabad         Urban Khichdi           8.7
#  Bangalore              Truffles           8.9
#  Chennai                 Toscano           8.8
#  Goa                Ritz Classic           8.5
#  Hyderabad               Exotica           8.9
#  Jaipur           Thali and More           8.8
#  Kochi                   Al Taza           8.8
#  Kolkata              Mitra Cafe           8.8
#  Lucknow    The Hazelnut Factory           8.7
#  Mumbai                Chaitanya           8.9
#  New Delhi     Natural Ice Cream           9.3
#  Pune          Natural Ice Cream           8.7
#  Raipur                  Hot 100           8.5

# %% [markdown]
# # Top 5 restaurants in each city

# %%
# Top 5 restaurants in each city
def get_restaurant(df, title):
    list_cities = list(df.City.unique())
    print(f'{len(list_cities)}')
    fig, axs = plt.subplots(len(list_cities), 1, figsize=(10, 60), facecolor="w", edgecolor="k")
    fig.subplots_adjust(hspace=0.5, wspace=0.001)
    axs = axs.ravel()
    for i, city in enumerate(list_cities):
        df_new = df[df["City"] == city]
        df_new.sort_values("Count", ascending=False, inplace=True)
        df_new = df_new.head(5)
        bars = axs[i].barh(
            df_new['Restaurant_Name'], df_new["Count"], color='#69b3a2'
        )
        axs[i].set_title(f"{title} in {city}")
        axs[i].bar_label(bars)

# %%
df_res_cnt= df.groupby(['City', 'Restaurant_Name'])['Restaurant_Name'].value_counts().to_frame().reset_index(level=1, drop=True).rename(columns={'Restaurant_Name':'Count'})
df_res_cnt=df_res_cnt.reset_index()
get_restaurant(df_res_cnt, "Top 5 restaurants")
# Out:
# 13
# C:\Users\admin\AppData\Local\Temp\ipykernel_6728\2766550143.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.sort_values("Count", ascending=False, inplace=True)

# %% [markdown]
# # Average Price by City

# %%
ax = df.groupby('City')['Prices'].mean().apply(lambda x: round(x, 0)).to_frame().reset_index().sort_values(by='Prices',
                                                                              ascending=False).plot.bar(x='City',y='Prices',figsize=(13,7))
ax.bar_label(container=ax.containers[0], color='Red')
plt.title("Cities by Avg. Item Prices")
plt.ylabel("Avg Prices")
plt.xlabel("City")
plt.show()

# %% [markdown]
# # Cities have the highest average delivery rating

# %%
#zomato services in cities based on delivery rating
df.groupby('City')['Delivery_Rating'].mean().apply(lambda x: round(x,2)).to_frame().sort_values(by='Delivery_Rating', ascending=False)
# Out:
#             Delivery_Rating
# City
#  Pune                  4.01
#  Hyderabad             3.98
#  Jaipur                3.98
#  Kolkata               3.98
#  Bangalore             3.97
#  Chennai               3.96
#  Lucknow               3.96
#  New Delhi             3.95
#  Ahmedabad             3.92
#  Kochi                 3.91
#  Mumbai                3.91
#  Raipur                3.85
#  Goa                   2.47

# %%
ax = df.groupby('City')['Delivery_Votes'].sum().sort_values(ascending=False).reset_index().plot.bar(x='City',y='Delivery_Votes',figsize=(15,8))
# ax.bar_label(container=ax.containers[0])
plt.ticklabel_format(useOffset=False,style='plain', axis='y')
plt.title("Total Votes by Cities")
plt.ylabel("Total Votes")
plt.xlabel("City")
plt.show()

# %% [markdown]
# # Most Expensive Dishes(Cuisine)

# %%
df.groupby(['City','Cuisine ','Item_Name'], as_index= False)['Prices'].max().sort_values(by='Prices',ascending=False).head(10)
# Out:
#              City  Cuisine   \
# 58292     Kolkata   Seafood
# 20205     Chennai   Chinese
# 58746     Lucknow    Bakery
# 20204     Chennai   Chinese
# 20200     Chennai   Chinese
# 58745     Lucknow    Bakery
# 84138      Raipur     Pizza
# 55846     Kolkata     Pizza
# 13889   Bangalore     Kebab
# 68834      Mumbai  Desserts
#
#                                                Item_Name    Prices
# 58292                             Bakra Massallam [8 kg]  12024.00
# 20205                          20 Person Mutton Biriyani   6500.00
# 58746                             THF Golden Boat Basket   5593.22
# 20204                         20 Person Chicken Biriyani   4900.00
# 20200                          15 Person Mutton Biriyani   4200.00
# 58745                            THF Extravaganza Basket   4025.42
# 84138  Grand Celebration:2 Biryanis (Non Veg)+4 porti...   3999.00
# 55846  Grand Celebration:2 Biryanis (Non Veg)+4 porti...   3999.00
# 13889  Grand Celebration:2 Biryanis (Non Veg)+4 porti...   3999.00
# 68834                                          Aeropress   3800.00

# %% [markdown]
# # Most Expensive Dishes(Cuisine) by City

# %%
df_city = df.groupby(['City','Cuisine ','Item_Name'], as_index= False)['Prices'].max()
idx = df_city.groupby('City')['Prices'].idxmax()
max_price = df_city.loc[idx]
max_price = max_price.set_index('City')
max_price
# Out:
#              Cuisine                                           Item_Name  \
# City
#  Ahmedabad      Shake                                   Shahi Indian Box
#  Bangalore      Kebab  Grand Celebration:2 Biryanis (Non Veg)+4 porti...
#  Chennai      Chinese                          20 Person Mutton Biriyani
#  Goa          Biryani                              Raan Biryani (Mutton)
#  Hyderabad    Biryani                        Mutton Biryani [10 Persons]
#  Jaipur     Beverages                                      Cake Dinosour
#  Kochi      Beverages            Party Bucket Chicken Biryani [9-10 Pax]
#  Kolkata      Seafood                             Bakra Massallam [8 kg]
#  Lucknow       Bakery                             THF Golden Boat Basket
#  Mumbai      Desserts                                          Aeropress
#  New Delhi  Beverages                           Party Pack For 6 Combo 2
#  Pune       Fast Food                            Badam Mamra [500 grams]
#  Raipur         Pizza  Grand Celebration:2 Biryanis (Non Veg)+4 porti...
#
#               Prices
# City
#  Ahmedabad   2599.00
#  Bangalore   3999.00
#  Chennai     6500.00
#  Goa         2300.00
#  Hyderabad   3250.00
#  Jaipur      3000.00
#  Kochi       2749.00
#  Kolkata    12024.00
#  Lucknow     5593.22
#  Mumbai      3800.00
#  New Delhi   2069.00
#  Pune        2560.00
#  Raipur      3999.00

# %% [markdown]
# # Average price of Dishes(Cuisine) by city

# %%
df_city = df.groupby(['City','Cuisine '], as_index= False)['Prices'].mean()
idx = df_city.groupby('City')['Prices'].idxmin()
avg_price = df_city.loc[idx]
avg_price = avg_price.set_index('City')
avg_price
# Out:
#                  Cuisine       Prices
# City
#  Ahmedabad  Maharashtrian  108.888889
#  Bangalore    Street Food   84.008850
#  Chennai     South Indian  159.846995
#  Goa         North Indian  120.154639
#  Hyderabad   South Indian   89.485294
#  Jaipur      North Indian  135.062241
#  Kochi          Ice Cream   35.833333
#  Kolkata        Ice Cream  182.560976
#  Lucknow              Tea   61.428571
#  Mumbai      South Indian   86.000000
#  New Delhi   North Indian   99.118182
#  Pune               Shake  137.876771
#  Raipur             Pizza  194.591645

# %% [markdown]
# # Number of Outlets of Well-Known Brands

# %%
plt.figure(figsize = (14,7))
ax = df['Restaurant_Name'].value_counts().head(20).plot.bar(color='purple')
ax.bar_label(container=ax.containers[0])

ax.legend(['Restaurants'])
plt.xlabel("Restaurants Name")
plt.ylabel("Count of Restaurants")
plt.title("Count of Outlets",fontsize =20, weight = 'bold')
plt.show()

# %% [markdown]
# # Bestseller and other categories

# %%
df['Best_Seller'].value_counts().sort_values(ascending= False)
# Out:
# NA                          95715
# BESTSELLER                  16992
# MUST TRY                     4151
# Not eligible for coupons     2440
# CHEF'S SPECIAL               1822
# SPICY                        1254
# Not on Pro                    657
# NEW                           455
# SEASONAL                       91
# Eggless available              34
# VEGAN                          26
# GLUTEN FREE                     9
# FODMAP FRIENDLY                 9
# DAIRY FREE                      2
# Name: Best_Seller, dtype: int64

# %%
plt.figure(figsize = (13,8))

df_new = df[df["Best_Seller"] != 'NA']
df_bestseller = df_new['Best_Seller'].value_counts().nlargest(5).sort_values(ascending= True)
my_colors = ["#FA8072", "#6495ED", "#40E0D0", "#808080", "#28B463"]

plt.pie(df_bestseller, colors=my_colors,labels= df_bestseller.index,autopct='%1.1f%%', pctdistance=0.85)

plt.title('Top 5 Best Sellers category')
plt.show()
